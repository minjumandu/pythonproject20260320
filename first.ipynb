# %% [markdown]
# # 2026-03-20

# %%
print('Hello Python')ㄴㅇㅀㅇㄴㅀ
# Out:
# Hello Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div align="left">
# <img src="./image.png" width="500">
# </div>

# %% [markdown]
# ## 여기서부터

# %%
print('안녕 파이썬'
# Out:
#   Cell In[11], line 1
#     print('안녕 파이썬'
#                   ^
# SyntaxError: incomplete input

# %%
print('안녕 파이썬')
# Out:
# 안녕 파이썬
